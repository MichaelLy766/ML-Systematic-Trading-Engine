# %%
# Data and analysis libraries
import polars as pl                         # Fast dataframes for financial data
import numpy as np                          # Numerical computing library
from datetime import datetime, timedelta    # Date and time operations
import random


# Machine learning libraries  
import torch                                # PyTorch framework
import torch.nn as nn                       # Neural network modules
import torch.optim as optim                 # Optimization algorithms
import research                             # Model building and training utilities


# Visualization and 
import altair as alt                        # Interactive visualization library

# data sources
import binance                              # Binance market data utilities

# %%
research.set_seed(42)

# %%
pl.Config.set_tbl_width_chars(200)
pl.Config.set_fmt_str_lengths(100)
pl.Config.set_tbl_cols(-1)  # Show all columns
# Out:
# polars.config.Config

# %%
# Trading pair symbol
sym = 'BTCUSDT'
# time horizon of time series (time interval)
time_interval = '1h'
# Max number of auto-regressive lags
max_lags = 4
# Forecast horizon in steps 
forecast_horizon = 1
# Sharpe annualized rate (so it's independent of time frequency)
annualized_rate = research.sharpe_annualization_factor(time_interval, 365, 24)

# %%
import binance
print(binance.__file__)
print([x for x in dir(binance) if "download" in x.lower()])
# Out:
# c:\Users\micha\Documents\Code\school\cpp\classes\spring-2026\mat_4860\quant_trading_strategy\ML-Systematic-Trading-Engine\binance.py
# ['download_and_unzip', 'download_date_range', 'download_ohlc_timeseries', 'download_timeseries', 'download_trades']

# %%
# Download Data
start_date = datetime(2024, 10, 29, 0, 0)
end_date = datetime(2025, 10, 9, 0, 0)
binance.download_date_range(sym, start_date, end_date)
# Out:
# Downloading BTCUSDT:  12%|█▏        | 41/346 [03:17<19:37,  3.86s/it]
# [ERROR] BTCUSDT 2024-12-08: [WinError 32] The process cannot access the file because it is being used by another process: 'data\\BTCUSDT-trades-2024-12-08.csv'
# Downloading BTCUSDT:  29%|██▊       | 99/346 [07:32<21:34,  5.24s/it]
# [ERROR] BTCUSDT 2025-02-05: [WinError 32] The process cannot access the file because it is being used by another process: 'data\\BTCUSDT-trades-2025-02-05.csv'
# Downloading BTCUSDT:  43%|████▎     | 150/346 [10:58<07:55,  2.42s/it]
# [ERROR] BTCUSDT 2025-03-27: [WinError 32] The process cannot access the file because it is being used by another process: 'data\\BTCUSDT-trades-2025-03-27.csv'
# Downloading BTCUSDT:  51%|█████▏    | 178/346 [12:46<08:20,  2.98s/it]
# [ERROR] BTCUSDT 2025-04-24: [WinError 32] The process cannot access the file because it is being used by another process: 'data\\BTCUSDT-trades-2025-04-24.csv'
# Downloading BTCUSDT:  69%|██████▉   | 239/346 [16:00<05:21,  3.01s/it]
# [ERROR] BTCUSDT 2025-06-24: [WinError 32] The process cannot access the file because it is being used by another process: 'data\\BTCUSDT-trades-2025-06-24.csv'
# Downloading BTCUSDT:  71%|███████▏  | 247/346 [16:19<04:05,  2.48s/it]
# [ERROR] BTCUSDT 2025-07-02: [WinError 32] The process cannot access the file because it is being used by another process: 'data\\BTCUSDT-trades-2025-07-02.csv'
# Downloading BTCUSDT:  73%|███████▎  | 254/346 [16:35<03:33,  2.32s/it]
# [ERROR] BTCUSDT 2025-07-09: [WinError 32] The process cannot access the file because it is being used by another process: 'data\\BTCUSDT-trades-2025-07-09.csv'
# Downloading BTCUSDT:  74%|███████▍  | 256/346 [16:44<04:52,  3.25s/it]
# [ERROR] BTCUSDT 2025-07-11: [WinError 32] The process cannot access the file because it is being used by another process: 'data\\BTCUSDT-trades-2025-07-11.csv'
# Downloading BTCUSDT:  79%|███████▉  | 274/346 [17:38<03:03,  2.55s/it]
# [ERROR] BTCUSDT 2025-07-29: [WinError 32] The process cannot access the file because it is being used by another process: 'data\\BTCUSDT-trades-2025-07-29.csv'
# Downloading BTCUSDT:  82%|████████▏ | 282/346 [18:00<02:45,  2.59s/it]
# [ERROR] BTCUSDT 2025-08-06: [WinError 32] The process cannot access the file because it is being used by another process: 'data\\BTCUSDT-trades-2025-08-06.csv'
# Downloading BTCUSDT:  83%|████████▎ | 286/346 [18:10<02:28,  2.47s/it]
# [ERROR] BTCUSDT 2025-08-10: [WinError 32] The process cannot access the file because it is being used by another process: 'data\\BTCUSDT-trades-2025-08-10.csv'
# Downloading BTCUSDT:  86%|████████▌ | 297/346 [18:45<02:10,  2.66s/it]
# [ERROR] BTCUSDT 2025-08-21: [WinError 32] The process cannot access the file because it is being used by another process: 'data\\BTCUSDT-trades-2025-08-21.csv'
# Downloading BTCUSDT:  88%|████████▊ | 304/346 [19:05<01:53,  2.69s/it]
# [ERROR] BTCUSDT 2025-08-28: [WinError 32] The process cannot access the file because it is being used by another process: 'data\\BTCUSDT-trades-2025-08-28.csv'
# Downloading BTCUSDT:  94%|█████████▍| 325/346 [19:55<00:46,  2.23s/it]
# [ERROR] BTCUSDT 2025-09-18: [WinError 32] The process cannot access the file because it is being used by another process: 'data\\BTCUSDT-trades-2025-09-18.csv'
# Downloading BTCUSDT:  96%|█████████▌| 333/346 [20:14<00:36,  2.77s/it]
# [ERROR] BTCUSDT 2025-09-26: [WinError 32] The process cannot access the file because it is being used by another process: 'data\\BTCUSDT-trades-2025-09-26.csv'
# Downloading BTCUSDT:  97%|█████████▋| 336/346 [20:20<00:23,  2.37s/it]
# [ERROR] BTCUSDT 2025-09-29: [WinError 32] The process cannot access the file because it is being used by another process: 'data\\BTCUSDT-trades-2025-09-29.csv'
# Downloading BTCUSDT: 100%|██████████| 346/346 [20:54<00:00,  3.63s/it]
