# %% [markdown]
# #### remember taker vs maker strat
#
# we need to pick, size of our trades, entry/exit signal, leverage (borrowing money)

# %%
import sys
import os
sys.path.append(os.path.abspath('..'))

import polars as pl
import numpy as np
from datetime import datetime, timedelta
import random

import torch
import torch.nn as nn
import torch.optim as optim
import research

import altair as alt

import binance

# %%
import models

model = models.LinearModel(2)

model.load_state_dict(torch.load('12h_2lag_model.pth', weights_only=True))
model.eval()
# Out:
# LinearModel(
#   (linear): Linear(in_features=2, out_features=1, bias=True)
# )

# %% [markdown]
# ### Model Params

# %%
research.print_model_params(model)
# Out:
# linear.weight:
# [[-0.00744509 -0.03174492]]
# linear.bias:
# [0.000905]

# %% [markdown]
# ### Mean Reversion

# %%
series = [-0.014, 0.011399, -0.012212, 0.01997, -0.01442, 0.01227]
mu = np.mean(series)
mean_reversion_df = pl.DataFrame({'log_return': series, 'mean': mu})
mean_reversion_df
# Out:
# shape: (6, 2)
# ┌────────────┬──────────┐
# │ log_return ┆ mean     │
# │ ---        ┆ ---      │
# │ f64        ┆ f64      │
# ╞════════════╪══════════╡
# │ -0.014     ┆ 0.000501 │
# │ 0.011399   ┆ 0.000501 │
# │ -0.012212  ┆ 0.000501 │
# │ 0.01997    ┆ 0.000501 │
# │ -0.01442   ┆ 0.000501 │
# │ 0.01227    ┆ 0.000501 │
# └────────────┴──────────┘

# %%
research.plot_multiple_lines(mean_reversion_df, ['log_return', 'mean'], 'Mean Reversion')

# %% [markdown]
# ## Strategy development

# %% [markdown]
# ### load time series

# %%
sym = 'BTCUSDT'
time_interval='8h'

ts = pl.read_csv(f"../historical_data/{sym}_{time_interval}_ohlc_updated.csv", try_parse_dates=True).sort('datetime')
ts
# Out:
# shape: (1_098, 5)
# ┌─────────────────────┬─────────┬─────────┬─────────┬─────────┐
# │ datetime            ┆ open    ┆ high    ┆ low     ┆ close   │
# │ ---                 ┆ ---     ┆ ---     ┆ ---     ┆ ---     │
# │ datetime[μs]        ┆ f64     ┆ f64     ┆ f64     ┆ f64     │
# ╞═════════════════════╪═════════╪═════════╪═════════╪═════════╡
# │ 2025-05-05 00:00:00 ┆ 94230.2 ┆ 94778.5 ┆ 93445.1 ┆ 94696.4 │
# │ 2025-05-05 08:00:00 ┆ 94696.4 ┆ 94726.8 ┆ 93559.6 ┆ 93726.0 │
# │ 2025-05-05 16:00:00 ┆ 93726.0 ┆ 95165.1 ┆ 93705.3 ┆ 94696.7 │
# │ 2025-05-06 00:00:00 ┆ 94696.7 ┆ 94893.3 ┆ 93961.0 ┆ 94350.0 │
# │ 2025-05-06 08:00:00 ┆ 94350.0 ┆ 94697.2 ┆ 93327.0 ┆ 94513.2 │
# │ …                   ┆ …       ┆ …       ┆ …       ┆ …       │
# │ 2026-05-04 08:00:00 ┆ 79663.4 ┆ 80528.9 ┆ 78128.3 ┆ 79976.7 │
# │ 2026-05-04 16:00:00 ┆ 79976.6 ┆ 80771.7 ┆ 79562.0 ┆ 79826.1 │
# │ 2026-05-05 00:00:00 ┆ 79826.1 ┆ 81278.2 ┆ 79761.2 ┆ 80815.8 │
# │ 2026-05-05 08:00:00 ┆ 80815.8 ┆ 81656.6 ┆ 80480.6 ┆ 81488.7 │
# │ 2026-05-05 16:00:00 ┆ 81488.7 ┆ 81745.4 ┆ 80716.8 ┆ 80861.9 │
# └─────────────────────┴─────────┴─────────┴─────────┴─────────┘

# %% [markdown]
# #### add target and features

# %%
forecast_horizon = 1
ts = research.add_log_return_features(ts, 'close', forecast_horizon, max_no_lags=3)
ts
# Out:
# shape: (1_098, 9)
# ┌────────────┬─────────┬─────────┬─────────┬───┬────────────┬────────────┬────────────┬────────────┐
# │ datetime   ┆ open    ┆ high    ┆ low     ┆ … ┆ close_log_ ┆ close_log_ ┆ close_log_ ┆ close_log_ │
# │ ---        ┆ ---     ┆ ---     ┆ ---     ┆   ┆ return     ┆ return_lag ┆ return_lag ┆ return_lag │
# │ datetime[μ ┆ f64     ┆ f64     ┆ f64     ┆   ┆ ---        ┆ _1         ┆ _2         ┆ _3         │
# │ s]         ┆         ┆         ┆         ┆   ┆ f64        ┆ ---        ┆ ---        ┆ ---        │
# │            ┆         ┆         ┆         ┆   ┆            ┆ f64        ┆ f64        ┆ f64        │
# ╞════════════╪═════════╪═════════╪═════════╪═══╪════════════╪════════════╪════════════╪════════════╡
# │ 2025-05-05 ┆ 94230.2 ┆ 94778.5 ┆ 93445.1 ┆ … ┆ null       ┆ null       ┆ null       ┆ null       │
# │ 00:00:00   ┆         ┆         ┆         ┆   ┆            ┆            ┆            ┆            │
# │ 2025-05-05 ┆ 94696.4 ┆ 94726.8 ┆ 93559.6 ┆ … ┆ -0.0103    ┆ null       ┆ null       ┆ null       │
# │ 08:00:00   ┆         ┆         ┆         ┆   ┆            ┆            ┆            ┆            │
# │ 2025-05-05 ┆ 93726.0 ┆ 95165.1 ┆ 93705.3 ┆ … ┆ 0.010304   ┆ -0.0103    ┆ null       ┆ null       │
# │ 16:00:00   ┆         ┆         ┆         ┆   ┆            ┆            ┆            ┆            │
# │ 2025-05-06 ┆ 94696.7 ┆ 94893.3 ┆ 93961.0 ┆ … ┆ -0.003668  ┆ 0.010304   ┆ -0.0103    ┆ null       │
# │ 00:00:00   ┆         ┆         ┆         ┆   ┆            ┆            ┆            ┆            │
# │ 2025-05-06 ┆ 94350.0 ┆ 94697.2 ┆ 93327.0 ┆ … ┆ 0.001728   ┆ -0.003668  ┆ 0.010304   ┆ -0.0103    │
# │ 08:00:00   ┆         ┆         ┆         ┆   ┆            ┆            ┆            ┆            │
# │ …          ┆ …       ┆ …       ┆ …       ┆ … ┆ …          ┆ …          ┆ …          ┆ …          │
# │ 2026-05-04 ┆ 79663.4 ┆ 80528.9 ┆ 78128.3 ┆ … ┆ 0.003924   ┆ 0.014344   ┆ -0.001224  ┆ 0.003933   │
# │ 08:00:00   ┆         ┆         ┆         ┆   ┆            ┆            ┆            ┆            │
# │ 2026-05-04 ┆ 79976.6 ┆ 80771.7 ┆ 79562.0 ┆ … ┆ -0.001885  ┆ 0.003924   ┆ 0.014344   ┆ -0.001224  │
# │ 16:00:00   ┆         ┆         ┆         ┆   ┆            ┆            ┆            ┆            │
# │ 2026-05-05 ┆ 79826.1 ┆ 81278.2 ┆ 79761.2 ┆ … ┆ 0.012322   ┆ -0.001885  ┆ 0.003924   ┆ 0.014344   │
# │ 00:00:00   ┆         ┆         ┆         ┆   ┆            ┆            ┆            ┆            │
# │ 2026-05-05 ┆ 80815.8 ┆ 81656.6 ┆ 80480.6 ┆ … ┆ 0.008292   ┆ 0.012322   ┆ -0.001885  ┆ 0.003924   │
# │ 08:00:00   ┆         ┆         ┆         ┆   ┆            ┆            ┆            ┆            │
# │ 2026-05-05 ┆ 81488.7 ┆ 81745.4 ┆ 80716.8 ┆ … ┆ -0.007722  ┆ 0.008292   ┆ 0.012322   ┆ -0.001885  │
# │ 16:00:00   ┆         ┆         ┆         ┆   ┆            ┆            ┆            ┆            │
# └────────────┴─────────┴─────────┴─────────┴───┴────────────┴────────────┴────────────┴────────────┘

# %%
test_size = 0.25
_, trades = research.timeseries_split(ts, test_size)
trades
# Out:
# shape: (275, 9)
# ┌────────────┬─────────┬─────────┬─────────┬───┬────────────┬────────────┬────────────┬────────────┐
# │ datetime   ┆ open    ┆ high    ┆ low     ┆ … ┆ close_log_ ┆ close_log_ ┆ close_log_ ┆ close_log_ │
# │ ---        ┆ ---     ┆ ---     ┆ ---     ┆   ┆ return     ┆ return_lag ┆ return_lag ┆ return_lag │
# │ datetime[μ ┆ f64     ┆ f64     ┆ f64     ┆   ┆ ---        ┆ _1         ┆ _2         ┆ _3         │
# │ s]         ┆         ┆         ┆         ┆   ┆ f64        ┆ ---        ┆ ---        ┆ ---        │
# │            ┆         ┆         ┆         ┆   ┆            ┆ f64        ┆ f64        ┆ f64        │
# ╞════════════╪═════════╪═════════╪═════════╪═══╪════════════╪════════════╪════════════╪════════════╡
# │ 2026-02-03 ┆ 78750.0 ┆ 79049.0 ┆ 77000.5 ┆ … ┆ -0.008362  ┆ 0.000729   ┆ -0.001373  ┆ 0.028159   │
# │ 08:00:00   ┆         ┆         ┆         ┆   ┆            ┆            ┆            ┆            │
# │ 2026-02-03 ┆ 78094.2 ┆ 78101.5 ┆ 72889.2 ┆ … ┆ -0.030708  ┆ -0.008362  ┆ 0.000729   ┆ -0.001373  │
# │ 16:00:00   ┆         ┆         ┆         ┆   ┆            ┆            ┆            ┆            │
# │ 2026-02-04 ┆ 75732.4 ┆ 76952.5 ┆ 75420.0 ┆ … ┆ 0.009809   ┆ -0.030708  ┆ -0.008362  ┆ 0.000729   │
# │ 00:00:00   ┆         ┆         ┆         ┆   ┆            ┆            ┆            ┆            │
# │ 2026-02-04 ┆ 76478.9 ┆ 76568.0 ┆ 73756.0 ┆ … ┆ -0.031505  ┆ 0.009809   ┆ -0.030708  ┆ -0.008362  │
# │ 08:00:00   ┆         ┆         ┆         ┆   ┆            ┆            ┆            ┆            │
# │ 2026-02-04 ┆ 74107.0 ┆ 74211.8 ┆ 71838.0 ┆ … ┆ -0.01317   ┆ -0.031505  ┆ 0.009809   ┆ -0.030708  │
# │ 16:00:00   ┆         ┆         ┆         ┆   ┆            ┆            ┆            ┆            │
# │ …          ┆ …       ┆ …       ┆ …       ┆ … ┆ …          ┆ …          ┆ …          ┆ …          │
# │ 2026-05-04 ┆ 79663.4 ┆ 80528.9 ┆ 78128.3 ┆ … ┆ 0.003924   ┆ 0.014344   ┆ -0.001224  ┆ 0.003933   │
# │ 08:00:00   ┆         ┆         ┆         ┆   ┆            ┆            ┆            ┆            │
# │ 2026-05-04 ┆ 79976.6 ┆ 80771.7 ┆ 79562.0 ┆ … ┆ -0.001885  ┆ 0.003924   ┆ 0.014344   ┆ -0.001224  │
# │ 16:00:00   ┆         ┆         ┆         ┆   ┆            ┆            ┆            ┆            │
# │ 2026-05-05 ┆ 79826.1 ┆ 81278.2 ┆ 79761.2 ┆ … ┆ 0.012322   ┆ -0.001885  ┆ 0.003924   ┆ 0.014344   │
# │ 00:00:00   ┆         ┆         ┆         ┆   ┆            ┆            ┆            ┆            │
# │ 2026-05-05 ┆ 80815.8 ┆ 81656.6 ┆ 80480.6 ┆ … ┆ 0.008292   ┆ 0.012322   ┆ -0.001885  ┆ 0.003924   │
# │ 08:00:00   ┆         ┆         ┆         ┆   ┆            ┆            ┆            ┆            │
# │ 2026-05-05 ┆ 81488.7 ┆ 81745.4 ┆ 80716.8 ┆ … ┆ -0.007722  ┆ 0.008292   ┆ 0.012322   ┆ -0.001885  │
# │ 16:00:00   ┆         ┆         ┆         ┆   ┆            ┆            ┆            ┆            │
# └────────────┴─────────┴─────────┴─────────┴───┴────────────┴────────────┴────────────┴────────────┘

# %% [markdown]
# #### strategy decision #1, entry/exit signal

# %%
# 1. time based. exit 8 hours later
# 2. predicate based. prediction, but until certain condition is satisfied, make prediction

# %% [markdown]
# ##### add model predictions

# %%
target = 'close_log_return'
features = [f'{target}_lag_2', f'{target}_lag_3']
trades = research.add_model_predictions(trades, model, features)
trades
# Out:
# shape: (275, 10)
# ┌─────────────┬─────────┬─────────┬─────────┬───┬─────────────┬────────────┬────────────┬──────────┐
# │ datetime    ┆ open    ┆ high    ┆ low     ┆ … ┆ close_log_r ┆ close_log_ ┆ close_log_ ┆ y_hat    │
# │ ---         ┆ ---     ┆ ---     ┆ ---     ┆   ┆ eturn_lag_1 ┆ return_lag ┆ return_lag ┆ ---      │
# │ datetime[μs ┆ f64     ┆ f64     ┆ f64     ┆   ┆ ---         ┆ _2         ┆ _3         ┆ f32      │
# │ ]           ┆         ┆         ┆         ┆   ┆ f64         ┆ ---        ┆ ---        ┆          │
# │             ┆         ┆         ┆         ┆   ┆             ┆ f64        ┆ f64        ┆          │
# ╞═════════════╪═════════╪═════════╪═════════╪═══╪═════════════╪════════════╪════════════╪══════════╡
# │ 2026-02-03  ┆ 78750.0 ┆ 79049.0 ┆ 77000.5 ┆ … ┆ 0.000729    ┆ -0.001373  ┆ 0.028159   ┆ 0.000021 │
# │ 08:00:00    ┆         ┆         ┆         ┆   ┆             ┆            ┆            ┆          │
# │ 2026-02-03  ┆ 78094.2 ┆ 78101.5 ┆ 72889.2 ┆ … ┆ -0.008362   ┆ 0.000729   ┆ -0.001373  ┆ 0.000943 │
# │ 16:00:00    ┆         ┆         ┆         ┆   ┆             ┆            ┆            ┆          │
# │ 2026-02-04  ┆ 75732.4 ┆ 76952.5 ┆ 75420.0 ┆ … ┆ -0.030708   ┆ -0.008362  ┆ 0.000729   ┆ 0.000944 │
# │ 00:00:00    ┆         ┆         ┆         ┆   ┆             ┆            ┆            ┆          │
# │ 2026-02-04  ┆ 76478.9 ┆ 76568.0 ┆ 73756.0 ┆ … ┆ 0.009809    ┆ -0.030708  ┆ -0.008362  ┆ 0.001399 │
# │ 08:00:00    ┆         ┆         ┆         ┆   ┆             ┆            ┆            ┆          │
# │ 2026-02-04  ┆ 74107.0 ┆ 74211.8 ┆ 71838.0 ┆ … ┆ -0.031505   ┆ 0.009809   ┆ -0.030708  ┆ 0.001807 │
# │ 16:00:00    ┆         ┆         ┆         ┆   ┆             ┆            ┆            ┆          │
# │ …           ┆ …       ┆ …       ┆ …       ┆ … ┆ …           ┆ …          ┆ …          ┆ …        │
# │ 2026-05-04  ┆ 79663.4 ┆ 80528.9 ┆ 78128.3 ┆ … ┆ 0.014344    ┆ -0.001224  ┆ 0.003933   ┆ 0.000789 │
# │ 08:00:00    ┆         ┆         ┆         ┆   ┆             ┆            ┆            ┆          │
# │ 2026-05-04  ┆ 79976.6 ┆ 80771.7 ┆ 79562.0 ┆ … ┆ 0.003924    ┆ 0.014344   ┆ -0.001224  ┆ 0.000837 │
# │ 16:00:00    ┆         ┆         ┆         ┆   ┆             ┆            ┆            ┆          │
# │ 2026-05-05  ┆ 79826.1 ┆ 81278.2 ┆ 79761.2 ┆ … ┆ -0.001885   ┆ 0.003924   ┆ 0.014344   ┆ 0.00042  │
# │ 00:00:00    ┆         ┆         ┆         ┆   ┆             ┆            ┆            ┆          │
# │ 2026-05-05  ┆ 80815.8 ┆ 81656.6 ┆ 80480.6 ┆ … ┆ 0.012322    ┆ -0.001885  ┆ 0.003924   ┆ 0.000794 │
# │ 08:00:00    ┆         ┆         ┆         ┆   ┆             ┆            ┆            ┆          │
# │ 2026-05-05  ┆ 81488.7 ┆ 81745.4 ┆ 80716.8 ┆ … ┆ 0.008292    ┆ 0.012322   ┆ -0.001885  ┆ 0.000873 │
# │ 16:00:00    ┆         ┆         ┆         ┆   ┆             ┆            ┆            ┆          │
# └─────────────┴─────────┴─────────┴─────────┴───┴─────────────┴────────────┴────────────┴──────────┘

# %% [markdown]
# ##### add directional signal

# %%
trades = trades.with_columns(pl.col('y_hat').sign().alias('dir_signal'))
trades
# Out:
# shape: (275, 11)
# ┌─────────────┬─────────┬─────────┬─────────┬───┬─────────────┬────────────┬──────────┬────────────┐
# │ datetime    ┆ open    ┆ high    ┆ low     ┆ … ┆ close_log_r ┆ close_log_ ┆ y_hat    ┆ dir_signal │
# │ ---         ┆ ---     ┆ ---     ┆ ---     ┆   ┆ eturn_lag_2 ┆ return_lag ┆ ---      ┆ ---        │
# │ datetime[μs ┆ f64     ┆ f64     ┆ f64     ┆   ┆ ---         ┆ _3         ┆ f32      ┆ f32        │
# │ ]           ┆         ┆         ┆         ┆   ┆ f64         ┆ ---        ┆          ┆            │
# │             ┆         ┆         ┆         ┆   ┆             ┆ f64        ┆          ┆            │
# ╞═════════════╪═════════╪═════════╪═════════╪═══╪═════════════╪════════════╪══════════╪════════════╡
# │ 2026-02-03  ┆ 78750.0 ┆ 79049.0 ┆ 77000.5 ┆ … ┆ -0.001373   ┆ 0.028159   ┆ 0.000021 ┆ 1.0        │
# │ 08:00:00    ┆         ┆         ┆         ┆   ┆             ┆            ┆          ┆            │
# │ 2026-02-03  ┆ 78094.2 ┆ 78101.5 ┆ 72889.2 ┆ … ┆ 0.000729    ┆ -0.001373  ┆ 0.000943 ┆ 1.0        │
# │ 16:00:00    ┆         ┆         ┆         ┆   ┆             ┆            ┆          ┆            │
# │ 2026-02-04  ┆ 75732.4 ┆ 76952.5 ┆ 75420.0 ┆ … ┆ -0.008362   ┆ 0.000729   ┆ 0.000944 ┆ 1.0        │
# │ 00:00:00    ┆         ┆         ┆         ┆   ┆             ┆            ┆          ┆            │
# │ 2026-02-04  ┆ 76478.9 ┆ 76568.0 ┆ 73756.0 ┆ … ┆ -0.030708   ┆ -0.008362  ┆ 0.001399 ┆ 1.0        │
# │ 08:00:00    ┆         ┆         ┆         ┆   ┆             ┆            ┆          ┆            │
# │ 2026-02-04  ┆ 74107.0 ┆ 74211.8 ┆ 71838.0 ┆ … ┆ 0.009809    ┆ -0.030708  ┆ 0.001807 ┆ 1.0        │
# │ 16:00:00    ┆         ┆         ┆         ┆   ┆             ┆            ┆          ┆            │
# │ …           ┆ …       ┆ …       ┆ …       ┆ … ┆ …           ┆ …          ┆ …        ┆ …          │
# │ 2026-05-04  ┆ 79663.4 ┆ 80528.9 ┆ 78128.3 ┆ … ┆ -0.001224   ┆ 0.003933   ┆ 0.000789 ┆ 1.0        │
# │ 08:00:00    ┆         ┆         ┆         ┆   ┆             ┆            ┆          ┆            │
# │ 2026-05-04  ┆ 79976.6 ┆ 80771.7 ┆ 79562.0 ┆ … ┆ 0.014344    ┆ -0.001224  ┆ 0.000837 ┆ 1.0        │
# │ 16:00:00    ┆         ┆         ┆         ┆   ┆             ┆            ┆          ┆            │
# │ 2026-05-05  ┆ 79826.1 ┆ 81278.2 ┆ 79761.2 ┆ … ┆ 0.003924    ┆ 0.014344   ┆ 0.00042  ┆ 1.0        │
# │ 00:00:00    ┆         ┆         ┆         ┆   ┆             ┆            ┆          ┆            │
# │ 2026-05-05  ┆ 80815.8 ┆ 81656.6 ┆ 80480.6 ┆ … ┆ -0.001885   ┆ 0.003924   ┆ 0.000794 ┆ 1.0        │
# │ 08:00:00    ┆         ┆         ┆         ┆   ┆             ┆            ┆          ┆            │
# │ 2026-05-05  ┆ 81488.7 ┆ 81745.4 ┆ 80716.8 ┆ … ┆ 0.012322    ┆ -0.001885  ┆ 0.000873 ┆ 1.0        │
# │ 16:00:00    ┆         ┆         ┆         ┆   ┆             ┆            ┆          ┆            │
# └─────────────┴─────────┴─────────┴─────────┴───┴─────────────┴────────────┴──────────┴────────────┘

# %% [markdown]
# #### calc trade log return

# %%
trades= trades.with_columns(
    (pl.col('close_log_return') * pl.col('dir_signal')).alias('trade_log_return')
)
trades
# Out:
# shape: (275, 12)
# ┌─────────────┬─────────┬─────────┬─────────┬───┬─────────────┬──────────┬────────────┬────────────┐
# │ datetime    ┆ open    ┆ high    ┆ low     ┆ … ┆ close_log_r ┆ y_hat    ┆ dir_signal ┆ trade_log_ │
# │ ---         ┆ ---     ┆ ---     ┆ ---     ┆   ┆ eturn_lag_3 ┆ ---      ┆ ---        ┆ return     │
# │ datetime[μs ┆ f64     ┆ f64     ┆ f64     ┆   ┆ ---         ┆ f32      ┆ f32        ┆ ---        │
# │ ]           ┆         ┆         ┆         ┆   ┆ f64         ┆          ┆            ┆ f64        │
# ╞═════════════╪═════════╪═════════╪═════════╪═══╪═════════════╪══════════╪════════════╪════════════╡
# │ 2026-02-03  ┆ 78750.0 ┆ 79049.0 ┆ 77000.5 ┆ … ┆ 0.028159    ┆ 0.000021 ┆ 1.0        ┆ -0.008362  │
# │ 08:00:00    ┆         ┆         ┆         ┆   ┆             ┆          ┆            ┆            │
# │ 2026-02-03  ┆ 78094.2 ┆ 78101.5 ┆ 72889.2 ┆ … ┆ -0.001373   ┆ 0.000943 ┆ 1.0        ┆ -0.030708  │
# │ 16:00:00    ┆         ┆         ┆         ┆   ┆             ┆          ┆            ┆            │
# │ 2026-02-04  ┆ 75732.4 ┆ 76952.5 ┆ 75420.0 ┆ … ┆ 0.000729    ┆ 0.000944 ┆ 1.0        ┆ 0.009809   │
# │ 00:00:00    ┆         ┆         ┆         ┆   ┆             ┆          ┆            ┆            │
# │ 2026-02-04  ┆ 76478.9 ┆ 76568.0 ┆ 73756.0 ┆ … ┆ -0.008362   ┆ 0.001399 ┆ 1.0        ┆ -0.031505  │
# │ 08:00:00    ┆         ┆         ┆         ┆   ┆             ┆          ┆            ┆            │
# │ 2026-02-04  ┆ 74107.0 ┆ 74211.8 ┆ 71838.0 ┆ … ┆ -0.030708   ┆ 0.001807 ┆ 1.0        ┆ -0.01317   │
# │ 16:00:00    ┆         ┆         ┆         ┆   ┆             ┆          ┆            ┆            │
# │ …           ┆ …       ┆ …       ┆ …       ┆ … ┆ …           ┆ …        ┆ …          ┆ …          │
# │ 2026-05-04  ┆ 79663.4 ┆ 80528.9 ┆ 78128.3 ┆ … ┆ 0.003933    ┆ 0.000789 ┆ 1.0        ┆ 0.003924   │
# │ 08:00:00    ┆         ┆         ┆         ┆   ┆             ┆          ┆            ┆            │
# │ 2026-05-04  ┆ 79976.6 ┆ 80771.7 ┆ 79562.0 ┆ … ┆ -0.001224   ┆ 0.000837 ┆ 1.0        ┆ -0.001885  │
# │ 16:00:00    ┆         ┆         ┆         ┆   ┆             ┆          ┆            ┆            │
# │ 2026-05-05  ┆ 79826.1 ┆ 81278.2 ┆ 79761.2 ┆ … ┆ 0.014344    ┆ 0.00042  ┆ 1.0        ┆ 0.012322   │
# │ 00:00:00    ┆         ┆         ┆         ┆   ┆             ┆          ┆            ┆            │
# │ 2026-05-05  ┆ 80815.8 ┆ 81656.6 ┆ 80480.6 ┆ … ┆ 0.003924    ┆ 0.000794 ┆ 1.0        ┆ 0.008292   │
# │ 08:00:00    ┆         ┆         ┆         ┆   ┆             ┆          ┆            ┆            │
# │ 2026-05-05  ┆ 81488.7 ┆ 81745.4 ┆ 80716.8 ┆ … ┆ -0.001885   ┆ 0.000873 ┆ 1.0        ┆ -0.007722  │
# │ 16:00:00    ┆         ┆         ┆         ┆   ┆             ┆          ┆            ┆            │
# └─────────────┴─────────┴─────────┴─────────┴───┴─────────────┴──────────┴────────────┴────────────┘

# %% [markdown]
# #### calc cumulative trade log return

# %%
trades = trades.with_columns(
    pl.col('trade_log_return').cum_sum().alias('cum_trade_log_return')
)
trades
# Out:
# shape: (275, 13)
# ┌─────────────┬─────────┬─────────┬─────────┬───┬──────────┬────────────┬─────────────┬────────────┐
# │ datetime    ┆ open    ┆ high    ┆ low     ┆ … ┆ y_hat    ┆ dir_signal ┆ trade_log_r ┆ cum_trade_ │
# │ ---         ┆ ---     ┆ ---     ┆ ---     ┆   ┆ ---      ┆ ---        ┆ eturn       ┆ log_return │
# │ datetime[μs ┆ f64     ┆ f64     ┆ f64     ┆   ┆ f32      ┆ f32        ┆ ---         ┆ ---        │
# │ ]           ┆         ┆         ┆         ┆   ┆          ┆            ┆ f64         ┆ f64        │
# ╞═════════════╪═════════╪═════════╪═════════╪═══╪══════════╪════════════╪═════════════╪════════════╡
# │ 2026-02-03  ┆ 78750.0 ┆ 79049.0 ┆ 77000.5 ┆ … ┆ 0.000021 ┆ 1.0        ┆ -0.008362   ┆ -0.008362  │
# │ 08:00:00    ┆         ┆         ┆         ┆   ┆          ┆            ┆             ┆            │
# │ 2026-02-03  ┆ 78094.2 ┆ 78101.5 ┆ 72889.2 ┆ … ┆ 0.000943 ┆ 1.0        ┆ -0.030708   ┆ -0.039071  │
# │ 16:00:00    ┆         ┆         ┆         ┆   ┆          ┆            ┆             ┆            │
# │ 2026-02-04  ┆ 75732.4 ┆ 76952.5 ┆ 75420.0 ┆ … ┆ 0.000944 ┆ 1.0        ┆ 0.009809    ┆ -0.029262  │
# │ 00:00:00    ┆         ┆         ┆         ┆   ┆          ┆            ┆             ┆            │
# │ 2026-02-04  ┆ 76478.9 ┆ 76568.0 ┆ 73756.0 ┆ … ┆ 0.001399 ┆ 1.0        ┆ -0.031505   ┆ -0.060767  │
# │ 08:00:00    ┆         ┆         ┆         ┆   ┆          ┆            ┆             ┆            │
# │ 2026-02-04  ┆ 74107.0 ┆ 74211.8 ┆ 71838.0 ┆ … ┆ 0.001807 ┆ 1.0        ┆ -0.01317    ┆ -0.073937  │
# │ 16:00:00    ┆         ┆         ┆         ┆   ┆          ┆            ┆             ┆            │
# │ …           ┆ …       ┆ …       ┆ …       ┆ … ┆ …        ┆ …          ┆ …           ┆ …          │
# │ 2026-05-04  ┆ 79663.4 ┆ 80528.9 ┆ 78128.3 ┆ … ┆ 0.000789 ┆ 1.0        ┆ 0.003924    ┆ 0.234185   │
# │ 08:00:00    ┆         ┆         ┆         ┆   ┆          ┆            ┆             ┆            │
# │ 2026-05-04  ┆ 79976.6 ┆ 80771.7 ┆ 79562.0 ┆ … ┆ 0.000837 ┆ 1.0        ┆ -0.001885   ┆ 0.2323     │
# │ 16:00:00    ┆         ┆         ┆         ┆   ┆          ┆            ┆             ┆            │
# │ 2026-05-05  ┆ 79826.1 ┆ 81278.2 ┆ 79761.2 ┆ … ┆ 0.00042  ┆ 1.0        ┆ 0.012322    ┆ 0.244622   │
# │ 00:00:00    ┆         ┆         ┆         ┆   ┆          ┆            ┆             ┆            │
# │ 2026-05-05  ┆ 80815.8 ┆ 81656.6 ┆ 80480.6 ┆ … ┆ 0.000794 ┆ 1.0        ┆ 0.008292    ┆ 0.252914   │
# │ 08:00:00    ┆         ┆         ┆         ┆   ┆          ┆            ┆             ┆            │
# │ 2026-05-05  ┆ 81488.7 ┆ 81745.4 ┆ 80716.8 ┆ … ┆ 0.000873 ┆ 1.0        ┆ -0.007722   ┆ 0.245192   │
# │ 16:00:00    ┆         ┆         ┆         ┆   ┆          ┆            ┆             ┆            │
# └─────────────┴─────────┴─────────┴─────────┴───┴──────────┴────────────┴─────────────┴────────────┘

# %% [markdown]
# #### display equity curve (log space)

# %%
research.plot_column(trades, 'cum_trade_log_return')
# Out:
# alt.Chart(...)

# %% [markdown]
# ## Strategy decision #2: Trade sizing

# %%
#1. constant trade size
#2. compounding trade size

# %% [markdown]
# ##### constant sizing

# %%
capital = 100
ratio = 1.0
trade_value = ratio * capital

# entry trade value and exit trade value
trades = trades.with_columns(
    pl.lit(trade_value).alias('entry_trade_value'),
    (trade_value * pl.col('trade_log_return').exp()).alias('exit_trade_value'),
    (trade_value / pl.col('open')).alias('trade_qty'),
).with_columns(
    (pl.col('trade_qty') * pl.col('dir_signal')).alias('signed_trade_qty')
)
trades.select('datetime', 'open', 'close', 'trade_log_return', 'y_hat', 'entry_trade_value', 'exit_trade_value', 'signed_trade_qty')
# Out:
# shape: (275, 8)
# ┌─────────────┬─────────┬─────────┬─────────────┬──────────┬─────────────┬────────────┬────────────┐
# │ datetime    ┆ open    ┆ close   ┆ trade_log_r ┆ y_hat    ┆ entry_trade ┆ exit_trade ┆ signed_tra │
# │ ---         ┆ ---     ┆ ---     ┆ eturn       ┆ ---      ┆ _value      ┆ _value     ┆ de_qty     │
# │ datetime[μs ┆ f64     ┆ f64     ┆ ---         ┆ f32      ┆ ---         ┆ ---        ┆ ---        │
# │ ]           ┆         ┆         ┆ f64         ┆          ┆ f64         ┆ f64        ┆ f64        │
# ╞═════════════╪═════════╪═════════╪═════════════╪══════════╪═════════════╪════════════╪════════════╡
# │ 2026-02-03  ┆ 78750.0 ┆ 78094.1 ┆ -0.008362   ┆ 0.000021 ┆ 100.0       ┆ 99.167237  ┆ 0.00127    │
# │ 08:00:00    ┆         ┆         ┆             ┆          ┆             ┆            ┆            │
# │ 2026-02-03  ┆ 78094.2 ┆ 75732.4 ┆ -0.030708   ┆ 0.000943 ┆ 100.0       ┆ 96.975828  ┆ 0.001281   │
# │ 16:00:00    ┆         ┆         ┆             ┆          ┆             ┆            ┆            │
# │ 2026-02-04  ┆ 75732.4 ┆ 76478.9 ┆ 0.009809    ┆ 0.000944 ┆ 100.0       ┆ 100.985708 ┆ 0.00132    │
# │ 00:00:00    ┆         ┆         ┆             ┆          ┆             ┆            ┆            │
# │ 2026-02-04  ┆ 76478.9 ┆ 74107.0 ┆ -0.031505   ┆ 0.001399 ┆ 100.0       ┆ 96.898622  ┆ 0.001308   │
# │ 08:00:00    ┆         ┆         ┆             ┆          ┆             ┆            ┆            │
# │ 2026-02-04  ┆ 74107.0 ┆ 73137.4 ┆ -0.01317    ┆ 0.001807 ┆ 100.0       ┆ 98.691622  ┆ 0.001349   │
# │ 16:00:00    ┆         ┆         ┆             ┆          ┆             ┆            ┆            │
# │ …           ┆ …       ┆ …       ┆ …           ┆ …        ┆ …           ┆ …          ┆ …          │
# │ 2026-05-04  ┆ 79663.4 ┆ 79976.7 ┆ 0.003924    ┆ 0.000789 ┆ 100.0       ┆ 100.393154 ┆ 0.001255   │
# │ 08:00:00    ┆         ┆         ┆             ┆          ┆             ┆            ┆            │
# │ 2026-05-04  ┆ 79976.6 ┆ 79826.1 ┆ -0.001885   ┆ 0.000837 ┆ 100.0       ┆ 99.811695  ┆ 0.00125    │
# │ 16:00:00    ┆         ┆         ┆             ┆          ┆             ┆            ┆            │
# │ 2026-05-05  ┆ 79826.1 ┆ 80815.8 ┆ 0.012322    ┆ 0.00042  ┆ 100.0       ┆ 101.23982  ┆ 0.001253   │
# │ 00:00:00    ┆         ┆         ┆             ┆          ┆             ┆            ┆            │
# │ 2026-05-05  ┆ 80815.8 ┆ 81488.7 ┆ 0.008292    ┆ 0.000794 ┆ 100.0       ┆ 100.832634 ┆ 0.001237   │
# │ 08:00:00    ┆         ┆         ┆             ┆          ┆             ┆            ┆            │
# │ 2026-05-05  ┆ 81488.7 ┆ 80861.9 ┆ -0.007722   ┆ 0.000873 ┆ 100.0       ┆ 99.230814  ┆ 0.001227   │
# │ 16:00:00    ┆         ┆         ┆             ┆          ┆             ┆            ┆            │
# └─────────────┴─────────┴─────────┴─────────────┴──────────┴─────────────┴────────────┴────────────┘

# %% [markdown]
# #### add trade gross profit and loss

# %%
trades = trades.with_columns(
    (pl.col('exit_trade_value') - pl.col('entry_trade_value')).alias('trade_gross_pnl')
)

trades.select('datetime', 'open', 'close', 'trade_log_return', 'y_hat', 'entry_trade_value', 'exit_trade_value', 'signed_trade_qty', 'trade_gross_pnl')
# Out:
# shape: (275, 9)
# ┌────────────┬─────────┬─────────┬────────────┬───┬────────────┬───────────┬───────────┬───────────┐
# │ datetime   ┆ open    ┆ close   ┆ trade_log_ ┆ … ┆ entry_trad ┆ exit_trad ┆ signed_tr ┆ trade_gro │
# │ ---        ┆ ---     ┆ ---     ┆ return     ┆   ┆ e_value    ┆ e_value   ┆ ade_qty   ┆ ss_pnl    │
# │ datetime[μ ┆ f64     ┆ f64     ┆ ---        ┆   ┆ ---        ┆ ---       ┆ ---       ┆ ---       │
# │ s]         ┆         ┆         ┆ f64        ┆   ┆ f64        ┆ f64       ┆ f64       ┆ f64       │
# ╞════════════╪═════════╪═════════╪════════════╪═══╪════════════╪═══════════╪═══════════╪═══════════╡
# │ 2026-02-03 ┆ 78750.0 ┆ 78094.1 ┆ -0.008362  ┆ … ┆ 100.0      ┆ 99.167237 ┆ 0.00127   ┆ -0.832763 │
# │ 08:00:00   ┆         ┆         ┆            ┆   ┆            ┆           ┆           ┆           │
# │ 2026-02-03 ┆ 78094.2 ┆ 75732.4 ┆ -0.030708  ┆ … ┆ 100.0      ┆ 96.975828 ┆ 0.001281  ┆ -3.024172 │
# │ 16:00:00   ┆         ┆         ┆            ┆   ┆            ┆           ┆           ┆           │
# │ 2026-02-04 ┆ 75732.4 ┆ 76478.9 ┆ 0.009809   ┆ … ┆ 100.0      ┆ 100.98570 ┆ 0.00132   ┆ 0.985708  │
# │ 00:00:00   ┆         ┆         ┆            ┆   ┆            ┆ 8         ┆           ┆           │
# │ 2026-02-04 ┆ 76478.9 ┆ 74107.0 ┆ -0.031505  ┆ … ┆ 100.0      ┆ 96.898622 ┆ 0.001308  ┆ -3.101378 │
# │ 08:00:00   ┆         ┆         ┆            ┆   ┆            ┆           ┆           ┆           │
# │ 2026-02-04 ┆ 74107.0 ┆ 73137.4 ┆ -0.01317   ┆ … ┆ 100.0      ┆ 98.691622 ┆ 0.001349  ┆ -1.308378 │
# │ 16:00:00   ┆         ┆         ┆            ┆   ┆            ┆           ┆           ┆           │
# │ …          ┆ …       ┆ …       ┆ …          ┆ … ┆ …          ┆ …         ┆ …         ┆ …         │
# │ 2026-05-04 ┆ 79663.4 ┆ 79976.7 ┆ 0.003924   ┆ … ┆ 100.0      ┆ 100.39315 ┆ 0.001255  ┆ 0.393154  │
# │ 08:00:00   ┆         ┆         ┆            ┆   ┆            ┆ 4         ┆           ┆           │
# │ 2026-05-04 ┆ 79976.6 ┆ 79826.1 ┆ -0.001885  ┆ … ┆ 100.0      ┆ 99.811695 ┆ 0.00125   ┆ -0.188305 │
# │ 16:00:00   ┆         ┆         ┆            ┆   ┆            ┆           ┆           ┆           │
# │ 2026-05-05 ┆ 79826.1 ┆ 80815.8 ┆ 0.012322   ┆ … ┆ 100.0      ┆ 101.23982 ┆ 0.001253  ┆ 1.23982   │
# │ 00:00:00   ┆         ┆         ┆            ┆   ┆            ┆           ┆           ┆           │
# │ 2026-05-05 ┆ 80815.8 ┆ 81488.7 ┆ 0.008292   ┆ … ┆ 100.0      ┆ 100.83263 ┆ 0.001237  ┆ 0.832634  │
# │ 08:00:00   ┆         ┆         ┆            ┆   ┆            ┆ 4         ┆           ┆           │
# │ 2026-05-05 ┆ 81488.7 ┆ 80861.9 ┆ -0.007722  ┆ … ┆ 100.0      ┆ 99.230814 ┆ 0.001227  ┆ -0.769186 │
# │ 16:00:00   ┆         ┆         ┆            ┆   ┆            ┆           ┆           ┆           │
# └────────────┴─────────┴─────────┴────────────┴───┴────────────┴───────────┴───────────┴───────────┘

# %% [markdown]
# #### Add transaction fees

# %%
taker_fee = binance.TAKER_FEE
maker_fee = binance.MAKER_FEE

trades = trades.with_columns(
    ((pl.col('entry_trade_value') * taker_fee + pl.col('exit_trade_value') * taker_fee) * pl.col('dir_signal').abs()).alias('taker_fee'),
    ((pl.col('entry_trade_value') * maker_fee + pl.col('exit_trade_value') * maker_fee) * pl.col('dir_signal').abs()).alias('maker_fee')
)

trades.select('datetime', 'open', 'close', 'trade_log_return', 'y_hat', 'entry_trade_value', 'exit_trade_value', 'signed_trade_qty', 'trade_gross_pnl', 'maker_fee', 'taker_fee')
# Out:
# shape: (275, 11)
# ┌────────────┬─────────┬─────────┬────────────┬───┬────────────┬───────────┬───────────┬───────────┐
# │ datetime   ┆ open    ┆ close   ┆ trade_log_ ┆ … ┆ signed_tra ┆ trade_gro ┆ maker_fee ┆ taker_fee │
# │ ---        ┆ ---     ┆ ---     ┆ return     ┆   ┆ de_qty     ┆ ss_pnl    ┆ ---       ┆ ---       │
# │ datetime[μ ┆ f64     ┆ f64     ┆ ---        ┆   ┆ ---        ┆ ---       ┆ f64       ┆ f64       │
# │ s]         ┆         ┆         ┆ f64        ┆   ┆ f64        ┆ f64       ┆           ┆           │
# ╞════════════╪═════════╪═════════╪════════════╪═══╪════════════╪═══════════╪═══════════╪═══════════╡
# │ 2026-02-03 ┆ 78750.0 ┆ 78094.1 ┆ -0.008362  ┆ … ┆ 0.00127    ┆ -0.832763 ┆ 0.089625  ┆ 0.089625  │
# │ 08:00:00   ┆         ┆         ┆            ┆   ┆            ┆           ┆           ┆           │
# │ 2026-02-03 ┆ 78094.2 ┆ 75732.4 ┆ -0.030708  ┆ … ┆ 0.001281   ┆ -3.024172 ┆ 0.088639  ┆ 0.088639  │
# │ 16:00:00   ┆         ┆         ┆            ┆   ┆            ┆           ┆           ┆           │
# │ 2026-02-04 ┆ 75732.4 ┆ 76478.9 ┆ 0.009809   ┆ … ┆ 0.00132    ┆ 0.985708  ┆ 0.090444  ┆ 0.090444  │
# │ 00:00:00   ┆         ┆         ┆            ┆   ┆            ┆           ┆           ┆           │
# │ 2026-02-04 ┆ 76478.9 ┆ 74107.0 ┆ -0.031505  ┆ … ┆ 0.001308   ┆ -3.101378 ┆ 0.088604  ┆ 0.088604  │
# │ 08:00:00   ┆         ┆         ┆            ┆   ┆            ┆           ┆           ┆           │
# │ 2026-02-04 ┆ 74107.0 ┆ 73137.4 ┆ -0.01317   ┆ … ┆ 0.001349   ┆ -1.308378 ┆ 0.089411  ┆ 0.089411  │
# │ 16:00:00   ┆         ┆         ┆            ┆   ┆            ┆           ┆           ┆           │
# │ …          ┆ …       ┆ …       ┆ …          ┆ … ┆ …          ┆ …         ┆ …         ┆ …         │
# │ 2026-05-04 ┆ 79663.4 ┆ 79976.7 ┆ 0.003924   ┆ … ┆ 0.001255   ┆ 0.393154  ┆ 0.090177  ┆ 0.090177  │
# │ 08:00:00   ┆         ┆         ┆            ┆   ┆            ┆           ┆           ┆           │
# │ 2026-05-04 ┆ 79976.6 ┆ 79826.1 ┆ -0.001885  ┆ … ┆ 0.00125    ┆ -0.188305 ┆ 0.089915  ┆ 0.089915  │
# │ 16:00:00   ┆         ┆         ┆            ┆   ┆            ┆           ┆           ┆           │
# │ 2026-05-05 ┆ 79826.1 ┆ 80815.8 ┆ 0.012322   ┆ … ┆ 0.001253   ┆ 1.23982   ┆ 0.090558  ┆ 0.090558  │
# │ 00:00:00   ┆         ┆         ┆            ┆   ┆            ┆           ┆           ┆           │
# │ 2026-05-05 ┆ 80815.8 ┆ 81488.7 ┆ 0.008292   ┆ … ┆ 0.001237   ┆ 0.832634  ┆ 0.090375  ┆ 0.090375  │
# │ 08:00:00   ┆         ┆         ┆            ┆   ┆            ┆           ┆           ┆           │
# │ 2026-05-05 ┆ 81488.7 ┆ 80861.9 ┆ -0.007722  ┆ … ┆ 0.001227   ┆ -0.769186 ┆ 0.089654  ┆ 0.089654  │
# │ 16:00:00   ┆         ┆         ┆            ┆   ┆            ┆           ┆           ┆           │
# └────────────┴─────────┴─────────┴────────────┴───┴────────────┴───────────┴───────────┴───────────┘

# %% [markdown]
# ##### calc net trade pnl

# %%
trades = trades.with_columns(
    (pl.col('trade_gross_pnl') - pl.col('maker_fee')).alias('trade_net_maker_pnl'),
    (pl.col('trade_gross_pnl') - pl.col('taker_fee')).alias('trade_net_taker_pnl'),
)


trades.select('datetime', 'open', 'close', 'trade_log_return', 'y_hat', 'entry_trade_value', 'exit_trade_value', 'signed_trade_qty', 'trade_gross_pnl', 'trade_net_taker_pnl', 'trade_net_maker_pnl')
# Out:
# shape: (275, 11)
# ┌────────────┬─────────┬─────────┬────────────┬───┬────────────┬───────────┬───────────┬───────────┐
# │ datetime   ┆ open    ┆ close   ┆ trade_log_ ┆ … ┆ signed_tra ┆ trade_gro ┆ trade_net ┆ trade_net │
# │ ---        ┆ ---     ┆ ---     ┆ return     ┆   ┆ de_qty     ┆ ss_pnl    ┆ _taker_pn ┆ _maker_pn │
# │ datetime[μ ┆ f64     ┆ f64     ┆ ---        ┆   ┆ ---        ┆ ---       ┆ l         ┆ l         │
# │ s]         ┆         ┆         ┆ f64        ┆   ┆ f64        ┆ f64       ┆ ---       ┆ ---       │
# │            ┆         ┆         ┆            ┆   ┆            ┆           ┆ f64       ┆ f64       │
# ╞════════════╪═════════╪═════════╪════════════╪═══╪════════════╪═══════════╪═══════════╪═══════════╡
# │ 2026-02-03 ┆ 78750.0 ┆ 78094.1 ┆ -0.008362  ┆ … ┆ 0.00127    ┆ -0.832763 ┆ -0.922388 ┆ -0.922388 │
# │ 08:00:00   ┆         ┆         ┆            ┆   ┆            ┆           ┆           ┆           │
# │ 2026-02-03 ┆ 78094.2 ┆ 75732.4 ┆ -0.030708  ┆ … ┆ 0.001281   ┆ -3.024172 ┆ -3.112811 ┆ -3.112811 │
# │ 16:00:00   ┆         ┆         ┆            ┆   ┆            ┆           ┆           ┆           │
# │ 2026-02-04 ┆ 75732.4 ┆ 76478.9 ┆ 0.009809   ┆ … ┆ 0.00132    ┆ 0.985708  ┆ 0.895264  ┆ 0.895264  │
# │ 00:00:00   ┆         ┆         ┆            ┆   ┆            ┆           ┆           ┆           │
# │ 2026-02-04 ┆ 76478.9 ┆ 74107.0 ┆ -0.031505  ┆ … ┆ 0.001308   ┆ -3.101378 ┆ -3.189983 ┆ -3.189983 │
# │ 08:00:00   ┆         ┆         ┆            ┆   ┆            ┆           ┆           ┆           │
# │ 2026-02-04 ┆ 74107.0 ┆ 73137.4 ┆ -0.01317   ┆ … ┆ 0.001349   ┆ -1.308378 ┆ -1.39779  ┆ -1.39779  │
# │ 16:00:00   ┆         ┆         ┆            ┆   ┆            ┆           ┆           ┆           │
# │ …          ┆ …       ┆ …       ┆ …          ┆ … ┆ …          ┆ …         ┆ …         ┆ …         │
# │ 2026-05-04 ┆ 79663.4 ┆ 79976.7 ┆ 0.003924   ┆ … ┆ 0.001255   ┆ 0.393154  ┆ 0.302977  ┆ 0.302977  │
# │ 08:00:00   ┆         ┆         ┆            ┆   ┆            ┆           ┆           ┆           │
# │ 2026-05-04 ┆ 79976.6 ┆ 79826.1 ┆ -0.001885  ┆ … ┆ 0.00125    ┆ -0.188305 ┆ -0.27822  ┆ -0.27822  │
# │ 16:00:00   ┆         ┆         ┆            ┆   ┆            ┆           ┆           ┆           │
# │ 2026-05-05 ┆ 79826.1 ┆ 80815.8 ┆ 0.012322   ┆ … ┆ 0.001253   ┆ 1.23982   ┆ 1.149262  ┆ 1.149262  │
# │ 00:00:00   ┆         ┆         ┆            ┆   ┆            ┆           ┆           ┆           │
# │ 2026-05-05 ┆ 80815.8 ┆ 81488.7 ┆ 0.008292   ┆ … ┆ 0.001237   ┆ 0.832634  ┆ 0.74226   ┆ 0.74226   │
# │ 08:00:00   ┆         ┆         ┆            ┆   ┆            ┆           ┆           ┆           │
# │ 2026-05-05 ┆ 81488.7 ┆ 80861.9 ┆ -0.007722  ┆ … ┆ 0.001227   ┆ -0.769186 ┆ -0.85884  ┆ -0.85884  │
# │ 16:00:00   ┆         ┆         ┆            ┆   ┆            ┆           ┆           ┆           │
# └────────────┴─────────┴─────────┴────────────┴───┴────────────┴───────────┴───────────┴───────────┘

# %% [markdown]
# #### display equity curves for constant sizing

# %%
def equity_curve(capital, col_name, suffix):
    return (capital + (pl.col(col_name).cum_sum())).alias(f'equity_curve_{suffix}')

trades = trades.with_columns(
    equity_curve(capital, 'trade_net_taker_pnl', 'taker'),
    equity_curve(capital, 'trade_net_maker_pnl', 'maker'),
    equity_curve(capital, 'trade_gross_pnl', 'gross'),
)

trades.select('datetime', 'equity_curve_gross', 'equity_curve_taker', 'equity_curve_maker')
# Out:
# shape: (275, 4)
# ┌─────────────────────┬────────────────────┬────────────────────┬────────────────────┐
# │ datetime            ┆ equity_curve_gross ┆ equity_curve_taker ┆ equity_curve_maker │
# │ ---                 ┆ ---                ┆ ---                ┆ ---                │
# │ datetime[μs]        ┆ f64                ┆ f64                ┆ f64                │
# ╞═════════════════════╪════════════════════╪════════════════════╪════════════════════╡
# │ 2026-02-03 08:00:00 ┆ 99.167237          ┆ 99.077612          ┆ 99.077612          │
# │ 2026-02-03 16:00:00 ┆ 96.143065          ┆ 95.964801          ┆ 95.964801          │
# │ 2026-02-04 00:00:00 ┆ 97.128772          ┆ 96.860065          ┆ 96.860065          │
# │ 2026-02-04 08:00:00 ┆ 94.027394          ┆ 93.670082          ┆ 93.670082          │
# │ 2026-02-04 16:00:00 ┆ 92.719016          ┆ 92.272292          ┆ 92.272292          │
# │ …                   ┆ …                  ┆ …                  ┆ …                  │
# │ 2026-05-04 08:00:00 ┆ 126.563585         ┆ 102.161632         ┆ 102.161632         │
# │ 2026-05-04 16:00:00 ┆ 126.37528          ┆ 101.883412         ┆ 101.883412         │
# │ 2026-05-05 00:00:00 ┆ 127.6151           ┆ 103.032674         ┆ 103.032674         │
# │ 2026-05-05 08:00:00 ┆ 128.447735         ┆ 103.774933         ┆ 103.774933         │
# │ 2026-05-05 16:00:00 ┆ 127.678548         ┆ 102.916093         ┆ 102.916093         │
# └─────────────────────┴────────────────────┴────────────────────┴────────────────────┘

# %%
research.plot_static_timeseries(trades, sym, 'equity_curve_taker',time_interval)

# %%
research.plot_static_timeseries(trades, sym, 'equity_curve_maker',time_interval)

# %% [markdown]
# ### calculate total net return using constant sizing

# %%
constant_sizing_net_return = trades['equity_curve_taker'][-1] / capital - 1
constant_sizing_net_return
# Out:
# 0.029160929203782437

# %% [markdown]
# #### compounding trade sizing
#
# reinvesting earnings basically.
#
# - if you put in 100, and earn two, your next trade you would put in 102
# - principle of time additivity

# %%
trades = trades.with_columns(
    ((pl.col('cum_trade_log_return').exp()) * capital).shift().fill_null(capital).alias('entry_trade_value'),
    ((pl.col('cum_trade_log_return').exp()) * capital).alias('exit_trade_value')
).with_columns(
    (pl.col('entry_trade_value') / pl.col('open') * pl.col('dir_signal')).alias('signed_trade_qty'),
    (pl.col('exit_trade_value') - pl.col('entry_trade_value')).alias('trade_gross_pnl'),
)

trades.select('datetime', 'open', 'close', 'trade_log_return', 'entry_trade_value', 'exit_trade_value', 'signed_trade_qty', 'trade_gross_pnl')
# Out:
# shape: (275, 8)
# ┌─────────────┬─────────┬─────────┬────────────┬────────────┬────────────┬────────────┬────────────┐
# │ datetime    ┆ open    ┆ close   ┆ trade_log_ ┆ entry_trad ┆ exit_trade ┆ signed_tra ┆ trade_gros │
# │ ---         ┆ ---     ┆ ---     ┆ return     ┆ e_value    ┆ _value     ┆ de_qty     ┆ s_pnl      │
# │ datetime[μs ┆ f64     ┆ f64     ┆ ---        ┆ ---        ┆ ---        ┆ ---        ┆ ---        │
# │ ]           ┆         ┆         ┆ f64        ┆ f64        ┆ f64        ┆ f64        ┆ f64        │
# ╞═════════════╪═════════╪═════════╪════════════╪════════════╪════════════╪════════════╪════════════╡
# │ 2026-02-03  ┆ 78750.0 ┆ 78094.1 ┆ -0.008362  ┆ 100.0      ┆ 99.167237  ┆ 0.00127    ┆ -0.832763  │
# │ 08:00:00    ┆         ┆         ┆            ┆            ┆            ┆            ┆            │
# │ 2026-02-03  ┆ 78094.2 ┆ 75732.4 ┆ -0.030708  ┆ 99.167237  ┆ 96.168249  ┆ 0.00127    ┆ -2.998988  │
# │ 16:00:00    ┆         ┆         ┆            ┆            ┆            ┆            ┆            │
# │ 2026-02-04  ┆ 75732.4 ┆ 76478.9 ┆ 0.009809   ┆ 96.168249  ┆ 97.116187  ┆ 0.00127    ┆ 0.947938   │
# │ 00:00:00    ┆         ┆         ┆            ┆            ┆            ┆            ┆            │
# │ 2026-02-04  ┆ 76478.9 ┆ 74107.0 ┆ -0.031505  ┆ 97.116187  ┆ 94.104246  ┆ 0.00127    ┆ -3.01194   │
# │ 08:00:00    ┆         ┆         ┆            ┆            ┆            ┆            ┆            │
# │ 2026-02-04  ┆ 74107.0 ┆ 73137.4 ┆ -0.01317   ┆ 94.104246  ┆ 92.873007  ┆ 0.00127    ┆ -1.23124   │
# │ 16:00:00    ┆         ┆         ┆            ┆            ┆            ┆            ┆            │
# │ …           ┆ …       ┆ …       ┆ …          ┆ …          ┆ …          ┆ …          ┆ …          │
# │ 2026-05-04  ┆ 79663.4 ┆ 79976.7 ┆ 0.003924   ┆ 125.892862 ┆ 126.387814 ┆ 0.00158    ┆ 0.494952   │
# │ 08:00:00    ┆         ┆         ┆            ┆            ┆            ┆            ┆            │
# │ 2026-05-04  ┆ 79976.6 ┆ 79826.1 ┆ -0.001885  ┆ 126.387814 ┆ 126.14982  ┆ 0.00158    ┆ -0.237994  │
# │ 16:00:00    ┆         ┆         ┆            ┆            ┆            ┆            ┆            │
# │ 2026-05-05  ┆ 79826.1 ┆ 80815.8 ┆ 0.012322   ┆ 126.14982  ┆ 127.71385  ┆ 0.00158    ┆ 1.564031   │
# │ 00:00:00    ┆         ┆         ┆            ┆            ┆            ┆            ┆            │
# │ 2026-05-05  ┆ 80815.8 ┆ 81488.7 ┆ 0.008292   ┆ 127.71385  ┆ 128.77724  ┆ 0.00158    ┆ 1.063389   │
# │ 08:00:00    ┆         ┆         ┆            ┆            ┆            ┆            ┆            │
# │ 2026-05-05  ┆ 81488.7 ┆ 80861.9 ┆ -0.007722  ┆ 128.77724  ┆ 127.786703 ┆ 0.00158    ┆ -0.990537  │
# │ 16:00:00    ┆         ┆         ┆            ┆            ┆            ┆            ┆            │
# └─────────────┴─────────┴─────────┴────────────┴────────────┴────────────┴────────────┴────────────┘

# %% [markdown]
# ##### add transaction fees

# %%
trades = research.add_tx_fees(trades, binance.MAKER_FEE, binance.TAKER_FEE)
trades.select('datetime', 'entry_trade_value', 'exit_trade_value', 'tx_fee_maker', 'tx_fee_taker')
# Out:
# shape: (275, 5)
# ┌─────────────────────┬───────────────────┬──────────────────┬──────────────┬──────────────┐
# │ datetime            ┆ entry_trade_value ┆ exit_trade_value ┆ tx_fee_maker ┆ tx_fee_taker │
# │ ---                 ┆ ---               ┆ ---              ┆ ---          ┆ ---          │
# │ datetime[μs]        ┆ f64               ┆ f64              ┆ f64          ┆ f64          │
# ╞═════════════════════╪═══════════════════╪══════════════════╪══════════════╪══════════════╡
# │ 2026-02-03 08:00:00 ┆ 100.0             ┆ 99.167237        ┆ 0.089625     ┆ 0.089625     │
# │ 2026-02-03 16:00:00 ┆ 99.167237         ┆ 96.168249        ┆ 0.087901     ┆ 0.087901     │
# │ 2026-02-04 00:00:00 ┆ 96.168249         ┆ 97.116187        ┆ 0.086978     ┆ 0.086978     │
# │ 2026-02-04 08:00:00 ┆ 97.116187         ┆ 94.104246        ┆ 0.086049     ┆ 0.086049     │
# │ 2026-02-04 16:00:00 ┆ 94.104246         ┆ 92.873007        ┆ 0.08414      ┆ 0.08414      │
# │ …                   ┆ …                 ┆ …                ┆ …            ┆ …            │
# │ 2026-05-04 08:00:00 ┆ 125.892862        ┆ 126.387814       ┆ 0.113526     ┆ 0.113526     │
# │ 2026-05-04 16:00:00 ┆ 126.387814        ┆ 126.14982        ┆ 0.113642     ┆ 0.113642     │
# │ 2026-05-05 00:00:00 ┆ 126.14982         ┆ 127.71385        ┆ 0.114239     ┆ 0.114239     │
# │ 2026-05-05 08:00:00 ┆ 127.71385         ┆ 128.77724        ┆ 0.115421     ┆ 0.115421     │
# │ 2026-05-05 16:00:00 ┆ 128.77724         ┆ 127.786703       ┆ 0.115454     ┆ 0.115454     │
# └─────────────────────┴───────────────────┴──────────────────┴──────────────┴──────────────┘

# %% [markdown]
# #### add trade net pnl

# %%
trades = trades.with_columns(
    (pl.col('trade_gross_pnl') - pl.col('tx_fee_taker')).alias('trade_net_taker_pnl')
)

trades.select('datetime', 'open', 'close', 'close_log_return', 'y_hat', 'entry_trade_value', 'exit_trade_value', 'trade_gross_pnl', 'trade_net_taker_pnl')
# Out:
# shape: (275, 9)
# ┌────────────┬─────────┬─────────┬────────────┬───┬────────────┬───────────┬───────────┬───────────┐
# │ datetime   ┆ open    ┆ close   ┆ close_log_ ┆ … ┆ entry_trad ┆ exit_trad ┆ trade_gro ┆ trade_net │
# │ ---        ┆ ---     ┆ ---     ┆ return     ┆   ┆ e_value    ┆ e_value   ┆ ss_pnl    ┆ _taker_pn │
# │ datetime[μ ┆ f64     ┆ f64     ┆ ---        ┆   ┆ ---        ┆ ---       ┆ ---       ┆ l         │
# │ s]         ┆         ┆         ┆ f64        ┆   ┆ f64        ┆ f64       ┆ f64       ┆ ---       │
# │            ┆         ┆         ┆            ┆   ┆            ┆           ┆           ┆ f64       │
# ╞════════════╪═════════╪═════════╪════════════╪═══╪════════════╪═══════════╪═══════════╪═══════════╡
# │ 2026-02-03 ┆ 78750.0 ┆ 78094.1 ┆ -0.008362  ┆ … ┆ 100.0      ┆ 99.167237 ┆ -0.832763 ┆ -0.922388 │
# │ 08:00:00   ┆         ┆         ┆            ┆   ┆            ┆           ┆           ┆           │
# │ 2026-02-03 ┆ 78094.2 ┆ 75732.4 ┆ -0.030708  ┆ … ┆ 99.167237  ┆ 96.168249 ┆ -2.998988 ┆ -3.086889 │
# │ 16:00:00   ┆         ┆         ┆            ┆   ┆            ┆           ┆           ┆           │
# │ 2026-02-04 ┆ 75732.4 ┆ 76478.9 ┆ 0.009809   ┆ … ┆ 96.168249  ┆ 97.116187 ┆ 0.947938  ┆ 0.86096   │
# │ 00:00:00   ┆         ┆         ┆            ┆   ┆            ┆           ┆           ┆           │
# │ 2026-02-04 ┆ 76478.9 ┆ 74107.0 ┆ -0.031505  ┆ … ┆ 97.116187  ┆ 94.104246 ┆ -3.01194  ┆ -3.09799  │
# │ 08:00:00   ┆         ┆         ┆            ┆   ┆            ┆           ┆           ┆           │
# │ 2026-02-04 ┆ 74107.0 ┆ 73137.4 ┆ -0.01317   ┆ … ┆ 94.104246  ┆ 92.873007 ┆ -1.23124  ┆ -1.315379 │
# │ 16:00:00   ┆         ┆         ┆            ┆   ┆            ┆           ┆           ┆           │
# │ …          ┆ …       ┆ …       ┆ …          ┆ … ┆ …          ┆ …         ┆ …         ┆ …         │
# │ 2026-05-04 ┆ 79663.4 ┆ 79976.7 ┆ 0.003924   ┆ … ┆ 125.892862 ┆ 126.38781 ┆ 0.494952  ┆ 0.381426  │
# │ 08:00:00   ┆         ┆         ┆            ┆   ┆            ┆ 4         ┆           ┆           │
# │ 2026-05-04 ┆ 79976.6 ┆ 79826.1 ┆ -0.001885  ┆ … ┆ 126.387814 ┆ 126.14982 ┆ -0.237994 ┆ -0.351636 │
# │ 16:00:00   ┆         ┆         ┆            ┆   ┆            ┆           ┆           ┆           │
# │ 2026-05-05 ┆ 79826.1 ┆ 80815.8 ┆ 0.012322   ┆ … ┆ 126.14982  ┆ 127.71385 ┆ 1.564031  ┆ 1.449792  │
# │ 00:00:00   ┆         ┆         ┆            ┆   ┆            ┆           ┆           ┆           │
# │ 2026-05-05 ┆ 80815.8 ┆ 81488.7 ┆ 0.008292   ┆ … ┆ 127.71385  ┆ 128.77724 ┆ 1.063389  ┆ 0.947968  │
# │ 08:00:00   ┆         ┆         ┆            ┆   ┆            ┆           ┆           ┆           │
# │ 2026-05-05 ┆ 81488.7 ┆ 80861.9 ┆ -0.007722  ┆ … ┆ 128.77724  ┆ 127.78670 ┆ -0.990537 ┆ -1.105991 │
# │ 16:00:00   ┆         ┆         ┆            ┆   ┆            ┆ 3         ┆           ┆           │
# └────────────┴─────────┴─────────┴────────────┴───┴────────────┴───────────┴───────────┴───────────┘

# %% [markdown]
# ### Display equity curve (compounding)

# %%
trades = research.add_equity_curve(trades, capital, 'trade_net_taker_pnl', 'taker')
research.plot_static_timeseries(trades, sym, 'equity_curve_taker', time_interval)

# %% [markdown]
# ### calculate total net return for compounding trade sizing

# %%
compound_total_net_return = trades['equity_curve_taker'][-1] / capital - 1
compound_total_net_return
# Out:
# 0.024369857883356216

# %%
constant_sizing_net_return
# Out:
# 0.029160929203782437

# %%
np.round(compound_total_net_return - constant_sizing_net_return, 3)
# Out:
# np.float64(-0.005)

# %% [markdown]
# ### Strategy decision #3, leverage

# %% [markdown]
# borrowing money?

# %%
leverage = 4
trades = research.add_compounding_trades(trades, capital, leverage, maker_fee, taker_fee)
trades
# Out:
# shape: (275, 27)
# ┌────────────┬─────────┬─────────┬─────────┬───┬────────────┬────────────┬────────────┬────────────┐
# │ datetime   ┆ open    ┆ high    ┆ low     ┆ … ┆ equity_cur ┆ equity_cur ┆ tx_fee_mak ┆ tx_fee_tak │
# │ ---        ┆ ---     ┆ ---     ┆ ---     ┆   ┆ ve_maker   ┆ ve_gross   ┆ er         ┆ er         │
# │ datetime[μ ┆ f64     ┆ f64     ┆ f64     ┆   ┆ ---        ┆ ---        ┆ ---        ┆ ---        │
# │ s]         ┆         ┆         ┆         ┆   ┆ f64        ┆ f64        ┆ f64        ┆ f64        │
# ╞════════════╪═════════╪═════════╪═════════╪═══╪════════════╪════════════╪════════════╪════════════╡
# │ 2026-02-03 ┆ 78750.0 ┆ 79049.0 ┆ 77000.5 ┆ … ┆ 96.310447  ┆ 96.668948  ┆ 0.358501   ┆ 0.358501   │
# │ 08:00:00   ┆         ┆         ┆         ┆   ┆            ┆            ┆            ┆            │
# │ 2026-02-03 ┆ 78094.2 ┆ 78101.5 ┆ 72889.2 ┆ … ┆ 83.962892  ┆ 84.672996  ┆ 0.351604   ┆ 0.351604   │
# │ 16:00:00   ┆         ┆         ┆         ┆   ┆            ┆            ┆            ┆            │
# │ 2026-02-04 ┆ 75732.4 ┆ 76952.5 ┆ 75420.0 ┆ … ┆ 87.40673   ┆ 88.464747  ┆ 0.347912   ┆ 0.347912   │
# │ 00:00:00   ┆         ┆         ┆         ┆   ┆            ┆            ┆            ┆            │
# │ 2026-02-04 ┆ 76478.9 ┆ 76568.0 ┆ 73756.0 ┆ … ┆ 75.014772  ┆ 76.416986  ┆ 0.344197   ┆ 0.344197   │
# │ 08:00:00   ┆         ┆         ┆         ┆   ┆            ┆            ┆            ┆            │
# │ 2026-02-04 ┆ 74107.0 ┆ 74211.8 ┆ 71838.0 ┆ … ┆ 69.753255  ┆ 71.492027  ┆ 0.336559   ┆ 0.336559   │
# │ 16:00:00   ┆         ┆         ┆         ┆   ┆            ┆            ┆            ┆            │
# │ …          ┆ …       ┆ …       ┆ …       ┆ … ┆ …          ┆ …          ┆ …          ┆ …          │
# │ 2026-05-04 ┆ 79663.4 ┆ 80528.9 ┆ 78128.3 ┆ … ┆ 105.98741  ┆ 205.551256 ┆ 0.454105   ┆ 0.454105   │
# │ 08:00:00   ┆         ┆         ┆         ┆   ┆            ┆            ┆            ┆            │
# │ 2026-05-04 ┆ 79976.6 ┆ 80771.7 ┆ 79562.0 ┆ … ┆ 104.580865 ┆ 204.599279 ┆ 0.454568   ┆ 0.454568   │
# │ 16:00:00   ┆         ┆         ┆         ┆   ┆            ┆            ┆            ┆            │
# │ 2026-05-05 ┆ 79826.1 ┆ 81278.2 ┆ 79761.2 ┆ … ┆ 110.380033 ┆ 210.855402 ┆ 0.456955   ┆ 0.456955   │
# │ 00:00:00   ┆         ┆         ┆         ┆   ┆            ┆            ┆            ┆            │
# │ 2026-05-05 ┆ 80815.8 ┆ 81656.6 ┆ 80480.6 ┆ … ┆ 114.171906 ┆ 215.108959 ┆ 0.461684   ┆ 0.461684   │
# │ 08:00:00   ┆         ┆         ┆         ┆   ┆            ┆            ┆            ┆            │
# │ 2026-05-05 ┆ 81488.7 ┆ 81745.4 ┆ 80716.8 ┆ … ┆ 109.747943 ┆ 211.146811 ┆ 0.461815   ┆ 0.461815   │
# │ 16:00:00   ┆         ┆         ┆         ┆   ┆            ┆            ┆            ┆            │
# └────────────┴─────────┴─────────┴─────────┴───┴────────────┴────────────┴────────────┴────────────┘

# %% [markdown]
# #### calculate total net return

# %%
trades['equity_curve_taker'][-1] / capital -1
# Out:
# 0.09747943153342487

# %% [markdown]
# #### increase to 8x leverage? (US legal limit)

# %%
leverage = 8
trades = research.add_compounding_trades(trades, capital, leverage, maker_fee, taker_fee)
trades
# Out:
# shape: (275, 27)
# ┌────────────┬─────────┬─────────┬─────────┬───┬────────────┬────────────┬────────────┬────────────┐
# │ datetime   ┆ open    ┆ high    ┆ low     ┆ … ┆ equity_cur ┆ equity_cur ┆ tx_fee_mak ┆ tx_fee_tak │
# │ ---        ┆ ---     ┆ ---     ┆ ---     ┆   ┆ ve_maker   ┆ ve_gross   ┆ er         ┆ er         │
# │ datetime[μ ┆ f64     ┆ f64     ┆ f64     ┆   ┆ ---        ┆ ---        ┆ ---        ┆ ---        │
# │ s]         ┆         ┆         ┆         ┆   ┆ f64        ┆ f64        ┆ f64        ┆ f64        │
# ╞════════════╪═════════╪═════════╪═════════╪═══╪════════════╪════════════╪════════════╪════════════╡
# │ 2026-02-03 ┆ 78750.0 ┆ 79049.0 ┆ 77000.5 ┆ … ┆ 92.620894  ┆ 93.337896  ┆ 0.717002   ┆ 0.717002   │
# │ 08:00:00   ┆         ┆         ┆         ┆   ┆            ┆            ┆            ┆            │
# │ 2026-02-03 ┆ 78094.2 ┆ 78101.5 ┆ 72889.2 ┆ … ┆ 67.925783  ┆ 69.345993  ┆ 0.703208   ┆ 0.703208   │
# │ 16:00:00   ┆         ┆         ┆         ┆   ┆            ┆            ┆            ┆            │
# │ 2026-02-04 ┆ 75732.4 ┆ 76952.5 ┆ 75420.0 ┆ … ┆ 74.813461  ┆ 76.929495  ┆ 0.695824   ┆ 0.695824   │
# │ 00:00:00   ┆         ┆         ┆         ┆   ┆            ┆            ┆            ┆            │
# │ 2026-02-04 ┆ 76478.9 ┆ 76568.0 ┆ 73756.0 ┆ … ┆ 50.029545  ┆ 52.833972  ┆ 0.688394   ┆ 0.688394   │
# │ 08:00:00   ┆         ┆         ┆         ┆   ┆            ┆            ┆            ┆            │
# │ 2026-02-04 ┆ 74107.0 ┆ 74211.8 ┆ 71838.0 ┆ … ┆ 39.506509  ┆ 42.984055  ┆ 0.673118   ┆ 0.673118   │
# │ 16:00:00   ┆         ┆         ┆         ┆   ┆            ┆            ┆            ┆            │
# │ …          ┆ …       ┆ …       ┆ …       ┆ … ┆ …          ┆ …          ┆ …          ┆ …          │
# │ 2026-05-04 ┆ 79663.4 ┆ 80528.9 ┆ 78128.3 ┆ … ┆ 111.97482  ┆ 311.102513 ┆ 0.90821    ┆ 0.90821    │
# │ 08:00:00   ┆         ┆         ┆         ┆   ┆            ┆            ┆            ┆            │
# │ 2026-05-04 ┆ 79976.6 ┆ 80771.7 ┆ 79562.0 ┆ … ┆ 109.16173  ┆ 309.198558 ┆ 0.909135   ┆ 0.909135   │
# │ 16:00:00   ┆         ┆         ┆         ┆   ┆            ┆            ┆            ┆            │
# │ 2026-05-05 ┆ 79826.1 ┆ 81278.2 ┆ 79761.2 ┆ … ┆ 120.760067 ┆ 321.710804 ┆ 0.913909   ┆ 0.913909   │
# │ 00:00:00   ┆         ┆         ┆         ┆   ┆            ┆            ┆            ┆            │
# │ 2026-05-05 ┆ 80815.8 ┆ 81656.6 ┆ 80480.6 ┆ … ┆ 128.343813 ┆ 330.217917 ┆ 0.923368   ┆ 0.923368   │
# │ 08:00:00   ┆         ┆         ┆         ┆   ┆            ┆            ┆            ┆            │
# │ 2026-05-05 ┆ 81488.7 ┆ 81745.4 ┆ 80716.8 ┆ … ┆ 119.495886 ┆ 322.293621 ┆ 0.92363    ┆ 0.92363    │
# │ 16:00:00   ┆         ┆         ┆         ┆   ┆            ┆            ┆            ┆            │
# └────────────┴─────────┴─────────┴─────────┴───┴────────────┴────────────┴────────────┴────────────┘

# %%
trades['equity_curve_taker'][-1] / capital -1
# Out:
# 0.1949588630668493

# %% [markdown]
# ##### wr hasnt changed

# %%
trades.select((pl.col('trade_log_return') > 0).mean())
# Out:
# shape: (1, 1)
# ┌──────────────────┐
# │ trade_log_return │
# │ ---              │
# │ f64              │
# ╞══════════════════╡
# │ 0.52             │
# └──────────────────┘

# %% [markdown]
# ##### basic liquidation model

# %% [markdown]
# closing a position

# %%
maintenance_margin = 0.005

def long_liquidation_price(p, l, mmr):
    return (p * l) / (l + 1 - mmr * l)

def short_liquidation_price(p, l, mmr):
    return (p * l) / (l - 1 + mmr * 1)

# %% [markdown]
# ##### show how leverage affects long positions

# %%
long_liquidation_price(200, 2, maintenance_margin)
# Out:
# 133.7792642140468

# %%
long_liquidation_price(200, 4, maintenance_margin)
# Out:
# 160.64257028112448

# %%
long_liquidation_price(200, 10, maintenance_margin)
# Out:
# 182.64840182648402

# %% [markdown]
# #### show how leverage affects short positions

# %%
short_liquidation_price(200, 2, maintenance_margin)
# Out:
# 398.00995024875624

# %%
short_liquidation_price(200, 4, maintenance_margin)
# Out:
# 266.22296173044924

# %% [markdown]
# ### add liquidation prices

# %%
leverage = 4

# %%
trades = trades.with_columns(
    pl.when(pl.col('dir_signal') == 1)
    .then(
        (pl.col('open') * leverage) / (leverage + 1 - maintenance_margin * leverage)
    )
    .when(pl.col('dir_signal') == -1)
    .then(
        (pl.col('open') * leverage) / (leverage - 1 + maintenance_margin * leverage )
    )
    .otherwise(None)
    .alias('liquidation_price')
)

trades.select('datetime', 'open', 'high', 'low', 'close', 'liquidation_price', 'dir_signal')
# Out:
# shape: (275, 7)
# ┌─────────────────────┬─────────┬─────────┬─────────┬─────────┬───────────────────┬────────────┐
# │ datetime            ┆ open    ┆ high    ┆ low     ┆ close   ┆ liquidation_price ┆ dir_signal │
# │ ---                 ┆ ---     ┆ ---     ┆ ---     ┆ ---     ┆ ---               ┆ ---        │
# │ datetime[μs]        ┆ f64     ┆ f64     ┆ f64     ┆ f64     ┆ f64               ┆ f32        │
# ╞═════════════════════╪═════════╪═════════╪═════════╪═════════╪═══════════════════╪════════════╡
# │ 2026-02-03 08:00:00 ┆ 78750.0 ┆ 79049.0 ┆ 77000.5 ┆ 78094.1 ┆ 63253.012048      ┆ 1.0        │
# │ 2026-02-03 16:00:00 ┆ 78094.2 ┆ 78101.5 ┆ 72889.2 ┆ 75732.4 ┆ 62726.26506       ┆ 1.0        │
# │ 2026-02-04 00:00:00 ┆ 75732.4 ┆ 76952.5 ┆ 75420.0 ┆ 76478.9 ┆ 60829.236948      ┆ 1.0        │
# │ 2026-02-04 08:00:00 ┆ 76478.9 ┆ 76568.0 ┆ 73756.0 ┆ 74107.0 ┆ 61428.835341      ┆ 1.0        │
# │ 2026-02-04 16:00:00 ┆ 74107.0 ┆ 74211.8 ┆ 71838.0 ┆ 73137.4 ┆ 59523.694779      ┆ 1.0        │
# │ …                   ┆ …       ┆ …       ┆ …       ┆ …       ┆ …                 ┆ …          │
# │ 2026-05-04 08:00:00 ┆ 79663.4 ┆ 80528.9 ┆ 78128.3 ┆ 79976.7 ┆ 63986.666667      ┆ 1.0        │
# │ 2026-05-04 16:00:00 ┆ 79976.6 ┆ 80771.7 ┆ 79562.0 ┆ 79826.1 ┆ 64238.232932      ┆ 1.0        │
# │ 2026-05-05 00:00:00 ┆ 79826.1 ┆ 81278.2 ┆ 79761.2 ┆ 80815.8 ┆ 64117.349398      ┆ 1.0        │
# │ 2026-05-05 08:00:00 ┆ 80815.8 ┆ 81656.6 ┆ 80480.6 ┆ 81488.7 ┆ 64912.289157      ┆ 1.0        │
# │ 2026-05-05 16:00:00 ┆ 81488.7 ┆ 81745.4 ┆ 80716.8 ┆ 80861.9 ┆ 65452.771084      ┆ 1.0        │
# └─────────────────────┴─────────┴─────────┴─────────┴─────────┴───────────────────┴────────────┘

# %% [markdown]
# ### add liquidation flag

# %%
trades = trades.with_columns([
    # worst price based on direction
    pl.when(pl.col('dir_signal') == 1)
        .then(pl.col('low'))
        .otherwise(pl.col('high'))
        .alias('worst_price'),
    # liquidation flag
    pl.when(
        (pl.col('dir_signal') == 1) & (pl.col('low') <= pl.col('liquidation_price'))
    )
    .then(True)
    .when(
        (pl.col('dir_signal') == -1) & (pl.col('high') >= pl.col('liquidation_price'))
    )
    .then(True)
    .otherwise(False)
    .alias('liquidated')
])

trades.select('datetime', 'open', 'high', 'low', 'close', 'liquidation_price', 'dir_signal', 'worst_price', 'liquidated')
# Out:
# shape: (275, 9)
# ┌────────────┬─────────┬─────────┬─────────┬───┬────────────┬────────────┬────────────┬────────────┐
# │ datetime   ┆ open    ┆ high    ┆ low     ┆ … ┆ liquidatio ┆ dir_signal ┆ worst_pric ┆ liquidated │
# │ ---        ┆ ---     ┆ ---     ┆ ---     ┆   ┆ n_price    ┆ ---        ┆ e          ┆ ---        │
# │ datetime[μ ┆ f64     ┆ f64     ┆ f64     ┆   ┆ ---        ┆ f32        ┆ ---        ┆ bool       │
# │ s]         ┆         ┆         ┆         ┆   ┆ f64        ┆            ┆ f64        ┆            │
# ╞════════════╪═════════╪═════════╪═════════╪═══╪════════════╪════════════╪════════════╪════════════╡
# │ 2026-02-03 ┆ 78750.0 ┆ 79049.0 ┆ 77000.5 ┆ … ┆ 63253.0120 ┆ 1.0        ┆ 77000.5    ┆ false      │
# │ 08:00:00   ┆         ┆         ┆         ┆   ┆ 48         ┆            ┆            ┆            │
# │ 2026-02-03 ┆ 78094.2 ┆ 78101.5 ┆ 72889.2 ┆ … ┆ 62726.2650 ┆ 1.0        ┆ 72889.2    ┆ false      │
# │ 16:00:00   ┆         ┆         ┆         ┆   ┆ 6          ┆            ┆            ┆            │
# │ 2026-02-04 ┆ 75732.4 ┆ 76952.5 ┆ 75420.0 ┆ … ┆ 60829.2369 ┆ 1.0        ┆ 75420.0    ┆ false      │
# │ 00:00:00   ┆         ┆         ┆         ┆   ┆ 48         ┆            ┆            ┆            │
# │ 2026-02-04 ┆ 76478.9 ┆ 76568.0 ┆ 73756.0 ┆ … ┆ 61428.8353 ┆ 1.0        ┆ 73756.0    ┆ false      │
# │ 08:00:00   ┆         ┆         ┆         ┆   ┆ 41         ┆            ┆            ┆            │
# │ 2026-02-04 ┆ 74107.0 ┆ 74211.8 ┆ 71838.0 ┆ … ┆ 59523.6947 ┆ 1.0        ┆ 71838.0    ┆ false      │
# │ 16:00:00   ┆         ┆         ┆         ┆   ┆ 79         ┆            ┆            ┆            │
# │ …          ┆ …       ┆ …       ┆ …       ┆ … ┆ …          ┆ …          ┆ …          ┆ …          │
# │ 2026-05-04 ┆ 79663.4 ┆ 80528.9 ┆ 78128.3 ┆ … ┆ 63986.6666 ┆ 1.0        ┆ 78128.3    ┆ false      │
# │ 08:00:00   ┆         ┆         ┆         ┆   ┆ 67         ┆            ┆            ┆            │
# │ 2026-05-04 ┆ 79976.6 ┆ 80771.7 ┆ 79562.0 ┆ … ┆ 64238.2329 ┆ 1.0        ┆ 79562.0    ┆ false      │
# │ 16:00:00   ┆         ┆         ┆         ┆   ┆ 32         ┆            ┆            ┆            │
# │ 2026-05-05 ┆ 79826.1 ┆ 81278.2 ┆ 79761.2 ┆ … ┆ 64117.3493 ┆ 1.0        ┆ 79761.2    ┆ false      │
# │ 00:00:00   ┆         ┆         ┆         ┆   ┆ 98         ┆            ┆            ┆            │
# │ 2026-05-05 ┆ 80815.8 ┆ 81656.6 ┆ 80480.6 ┆ … ┆ 64912.2891 ┆ 1.0        ┆ 80480.6    ┆ false      │
# │ 08:00:00   ┆         ┆         ┆         ┆   ┆ 57         ┆            ┆            ┆            │
# │ 2026-05-05 ┆ 81488.7 ┆ 81745.4 ┆ 80716.8 ┆ … ┆ 65452.7710 ┆ 1.0        ┆ 80716.8    ┆ false      │
# │ 16:00:00   ┆         ┆         ┆         ┆   ┆ 84         ┆            ┆            ┆            │
# └────────────┴─────────┴─────────┴─────────┴───┴────────────┴────────────┴────────────┴────────────┘

# %% [markdown]
# ### find liquidated trades

# %%
trades.filter(pl.col('liquidated') == True)
# Out:
# shape: (0, 30)
# ┌──────────────┬──────┬──────┬─────┬───┬──────────────┬─────────────────┬─────────────┬────────────┐
# │ datetime     ┆ open ┆ high ┆ low ┆ … ┆ tx_fee_taker ┆ liquidation_pri ┆ worst_price ┆ liquidated │
# │ ---          ┆ ---  ┆ ---  ┆ --- ┆   ┆ ---          ┆ ce              ┆ ---         ┆ ---        │
# │ datetime[μs] ┆ f64  ┆ f64  ┆ f64 ┆   ┆ f64          ┆ ---             ┆ f64         ┆ bool       │
# │              ┆      ┆      ┆     ┆   ┆              ┆ f64             ┆             ┆            │
# ╞══════════════╪══════╪══════╪═════╪═══╪══════════════╪═════════════════╪═════════════╪════════════╡
# └──────────────┴──────┴──────┴─────┴───┴──────────────┴─────────────────┴─────────────┴────────────┘
